# %% [markdown]
# # Clone the Repository:

# %%
! git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1191, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 1191 (delta 2), reused 6 (delta 2), pack-reused 1185
# Receiving objects: 100% (1191/1191), 74.23 MiB | 27.73 MiB/s, done.
# Resolving deltas: 100% (511/511), done.

# %% [markdown]
# # Change the directory Yolov7

# %%
# %cd /content/yolov7
# Out:
# /content/yolov7

# %% [markdown]
# # Install Required Dependies from YOLOV7:

# %%
! pip install -r /content/yolov7/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 17.6 MB/s eta 0:00:00
# ...

# %%
! pip install wget
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=9f21757e6111be2faf2f2d610a5a02b8991fe0b7051315045c43b02f705a2a5f
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...

# %% [markdown]
# # Download the YOLOV7 weight file from repository:
# https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt

# %% [markdown]
# # Test the weights with sample images form YOLOV7 directory:
#
# Tested Images results will be stored in runs folder....

# %%
! python /content/yolov7/detect.py --weights /content/yolov7.pt --conf 0.25 --img-size 640 --source /content/yolov7/inference/images/zidane.jpg
# Out:
# Namespace(weights=['/content/yolov7.pt'], source='/content/yolov7/inference/images/zidane.jpg', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-126-g84932d7 torch 2.0.1+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6652669 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
# ...

# %% [markdown]
# # Train the yolov7 weights with our custom dataset....
# 1. create the custom yaml file..
# 2. created customyaml should be stored in yolov7 data folder...
# 3. After finished training find the best.pt weights in runs/train/vehicledetection/weights/best.pt.....

# %%
# !python /content/yolov7/train.py --workers 4 --batch-size 4 --data /content/yolov7/data/customdata.yaml --img-size 640 --cfg /content/yolov7/cfg/training/yolov7.yaml --weights /content/yolov7.pt --name vehicledetection --hyp /content/yolov7/data/hyp.scratch.custom.yaml --device 0 --epochs 50
# Out:
# 2023-08-06 11:24:11.465241: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-06 11:24:12.344195: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# YOLOR 🚀 v0.1-126-g84932d7 torch 2.0.1+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# ...

# %% [markdown]
# # Test the our own data vedios....

# %%
! python /content/yolov7/detect.py  --source /content/yolov7/inference/images/ScooterCar.mp4 --weights /content/yolov7/runs/train/vehicledetection2/weights/best.pt --conf 0.25 --name Vehicledetection
# Out:
# Namespace(weights=['/content/yolov7/runs/train/vehicledetection2/weights/best.pt'], source='/content/yolov7/inference/images/ScooterCar.mp4', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='Vehicledetection', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-126-g84932d7 torch 2.0.1+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...
